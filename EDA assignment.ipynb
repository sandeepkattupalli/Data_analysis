# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv(r"C:\Users\Lenovo\Downloads\Weather_Data.csv")

# %%
d_copy=d.copy()

# %%
d_copy
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa        Weather
# ...

# %%
d_copy.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.3              -3.5         18                9
# 1  1/1/2012 1:00     7.4               2.8         20               24
# 2  1/1/2012 2:00    15.7              13.4         21               26
# 3  1/1/2012 3:00     4.9              -2.6         27               15
# 4  1/1/2012 4:00   -13.4             -19.7         30                4
# 5  1/1/2012 5:00    -3.3              -9.9         30                0
# 6  1/1/2012 6:00     3.8               1.2         30               19
# 7  1/1/2012 7:00    12.0              10.0         31               17
# 8  1/1/2012 8:00    14.8              10.9         34               11
# 9  1/1/2012 9:00    20.0               3.8         35               17
#
#    Visibility_km  Press_kPa        Weather
# 0           25.0      98.67          Clear
# 1           24.1      99.37           Rain
# 2           25.0      99.84         Cloudy
# ...

# %%
d_copy.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
d_copy.shape
# Out:
# (8784, 8)

# %%
d_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# 1) Find the number of times when the 'Weather is exactly Clear'.

# %%
d_copy["Wind Speed_km/h"].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %% [markdown]
# 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
d_copy["Weather"].value_counts().Clear
# Out:
# 1326

# %% [markdown]
# 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
k=d_copy.groupby("Wind Speed_km/h")
len(k.get_group(4))
# Out:
# 474

# %% [markdown]
# 4.Find out all the Null Values in the data

# %%
d_copy.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# 5.Rename the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
d_copy.rename(columns={"Weather":"Weather Condition"},inplace=True)

# %%
d_copy
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      1/1/2012 0:00    -1.3              -3.5         18                9
# 1      1/1/2012 1:00     7.4               2.8         20               24
# 2      1/1/2012 2:00    15.7              13.4         21               26
# 3      1/1/2012 3:00     4.9              -2.6         27               15
# 4      1/1/2012 4:00   -13.4             -19.7         30                4
# ...              ...     ...               ...        ...              ...
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
#  6) What is the mean 'Visibility' ?

# %%
d_copy["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# 7) What is the Standard Deviation of 'Pressure' in this data?

# %%
d_copy["Press_kPa"].std()
# Out:
# 0.8440047459486459

# %% [markdown]
# 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
d_copy["Rel Hum_%"].var()
# Out:
# 286.2485501985015

# %% [markdown]
# 9) Find all instances when 'Snow' was recorded

# %%
d_copy[d_copy["Weather Condition"] == "Snow"]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11     1/1/2012 11:00    -6.2              -9.6         37               35
# 70     3/1/2012 22:00    -4.0              -6.6         62               22
# 73      4/1/2012 1:00     2.3              -3.4         64               35
# 105     5/1/2012 9:00    -1.8              -4.2         73               15
# 112    5/1/2012 16:00     1.7              -0.3         75                6
# ...               ...     ...               ...        ...              ...
# 8573  9/22/2012 13:00    -6.0             -10.2         82               19
# 8650  9/25/2012 18:00    -4.6              -6.6         52                4
# 8671  9/26/2012 15:00    -5.9             -10.5         60               13
# 8713   9/28/2012 1:00    -5.2              -7.8         72               33
# 8734   9/28/2012 8:00     0.7              -1.2         79               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
# 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
d_copy[(d_copy["Wind Speed_km/h"] > 24) & (d_copy["Visibility_km"] == 25)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2       1/1/2012 2:00    15.7              13.4         21               26
# 73      4/1/2012 1:00     2.3              -3.4         64               35
# 126     6/1/2012 6:00    10.0               5.4         77               39
# 158    7/1/2012 14:00     1.9              -2.1         87               26
# 184    8/1/2012 16:00    14.2               9.2         35               44
# ...               ...     ...               ...        ...              ...
# 8707   9/27/2012 5:00    -1.0              -6.0         70               33
# 8714  9/28/2012 10:00     2.6               0.3         72               26
# 8738  9/29/2012 10:00    22.8              12.3         80               28
# 8745  9/29/2012 17:00   -10.3             -12.9         82               28
# 8776  9/30/2012 23:00    19.2              13.2         93               43
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
# 11) What is the Mean value of each column against each 'Weather Condition ?

# %% [markdown]
# . 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
d_copy.groupby("Weather Condition").agg(["min","max"])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather Condition
# Clear                                       1/1/2012 0:00     9/9/2012 4:00
# Cloudy                                     1/1/2012 10:00     9/9/2012 6:00
# Drizzle                                   1/18/2012 16:00   9/15/2012 22:00
# Drizzle,Fog                               1/28/2012 12:00    9/6/2012 10:00
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00    7/24/2012 5:00
# Drizzle,Snow                               3/17/2012 1:00     5/2/2012 9:00
# Drizzle,Snow,Fog                           1/25/2012 1:00   9/21/2012 12:00
# Fog                                        1/1/2012 13:00     9/8/2012 5:00
# Freezing Drizzle                           2/29/2012 3:00    8/21/2012 5:00
# Freezing Drizzle,Fog                      10/15/2012 4:00    7/26/2012 6:00
# ...

# %% [markdown]
# 13) Show all the Records where Weather Condition is Fog

# %%
d_copy[d_copy["Weather Condition"] == "Fog"]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13     1/1/2012 13:00     9.5               7.8         40               13
# 53      3/1/2012 5:00    -3.6              -4.3         57                7
# 136    6/1/2012 16:00    14.8              13.5         80               19
# 197     9/1/2012 5:00     2.1               0.7         43               11
# 278   12/1/2012 14:00     1.2               0.6         70               13
# ...               ...     ...               ...        ...              ...
# 8475  9/18/2012 11:00     6.2               5.4         56                7
# 8511  9/19/2012 22:00    15.7              15.4         66                7
# 8518   9/19/2012 8:00    -2.9              -4.5         68                6
# 8537   9/20/2012 3:00    -0.5              -2.1         74                7
# 8771  9/30/2012 19:00    12.8              12.2         91               19
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
# 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'

# %%
d_copy[(d_copy["Weather Condition"] == "Clear") | (d_copy["Visibility_km"] > 40)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012 0:00    -1.3              -3.5         18                9
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 16     1/1/2012 16:00    23.8              17.6         42                9
# 17     1/1/2012 17:00    -6.8              -9.8         42               20
# 18     1/1/2012 18:00     2.3              -2.4         42                6
# ...               ...     ...               ...        ...              ...
# 8774  9/30/2012 21:00    23.0              14.7         92               13
# 8777   9/30/2012 3:00     9.3               5.8         95                9
# 8779   9/30/2012 5:00     1.4              -3.7         97               22
# 8780   9/30/2012 6:00    -4.6              -9.5         98               11
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
# 15) Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# or
# B. 'Visibility is above 40'

# %%
d_copy[((d_copy["Weather Condition"] == "Clear") & (d_copy["Rel Hum_%"] > 50)) | (d_copy["Visibility_km"] > 40)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9       1/1/2012 9:00    20.0               3.8         35               17
# 17     1/1/2012 17:00    -6.8              -9.8         42               20
# 18     1/1/2012 18:00     2.3              -2.4         42                6
# 19     1/1/2012 19:00   -12.7             -17.2         43               17
# 23     1/1/2012 23:00    29.5              16.8         45                4
# ...               ...     ...               ...        ...              ...
# 8774  9/30/2012 21:00    23.0              14.7         92               13
# 8777   9/30/2012 3:00     9.3               5.8         95                9
# 8779   9/30/2012 5:00     1.4              -3.7         97               22
# 8780   9/30/2012 6:00    -4.6              -9.5         98               11
# 8781   9/30/2012 7:00     1.5              -6.3         99               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...
